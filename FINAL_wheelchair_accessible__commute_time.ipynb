# %% [markdown]
# # Data Preprocessing for Google Maps Queries
# ### Before performing the automated commute‑time extraction, the dataset underwent a preprocessing step to make the station names compatible with Google Maps queries. Many stations in the original data contained abbreviations such as LU for London Underground, DLR for Docklands Light Railway, NR for National Rail, or H&C for Hammersmith & City. These shorthand notations are often not recognized by Google Maps, which would result in failed searches or inaccurate routing. To address this, each station name was scanned with regular expressions to detect and remove these abbreviations, replacing them with the corresponding full transport system names. This produced clean, standardized station names that can be reliably interpreted by Google Maps in the subsequent Playwright‑based web‑scraping process, ensuring that all origin–destination pairs are correctly located and transit routes can be retrieved without interruption.

# %%
import pandas as pd
import re

transport_abbreviations = {
    'LU': 'London Underground',
    'DLR': 'Docklands Light Railway',
    'NR': 'National Rail',
    'TfL': 'Transport for London',
    'H&C': 'Hammersmith & City',
    'EL': 'Elizabeth Line',
    '(Bak)': 'Bakerloo',
    '(H&C)': 'Hammersmith & City'
}

def replace_abbreviation(station):
    if not isinstance(station, str):
        return ""
    for abbr, full in transport_abbreviations.items():
        pattern = rf"\s*\(?{re.escape(abbr)}\)?\s*$"
        if re.search(pattern, station):
            station_name = re.sub(pattern, '', station).strip()
            return f"{station_name} {full}"
    return station.strip()

df = pd.read_csv("frequent_routes_final_origin.csv")
df.columns = df.columns.str.strip()

df['Start_Station'] = df['Start_Station'].apply(replace_abbreviation)
df['End_Station'] = df['End_Station'].apply(replace_abbreviation)

df = df[['Start_Station', 'End_Station', 'Count']]

output_path = "/content/frequent_routes_final.csv"
df.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"finished and saved：{output_path}")
# Out:
# finished and saved：/content/frequent_routes_final.csv

# %% [markdown]
# # Automated Commute Time Extraction via Web Scraping
# ### Since the Google Maps API does not provide step‑free or wheelchair‑accessible route information, it is not possible to directly obtain total commute times for accessible journeys using the API alone. To address this limitation, we implemented an automated web‑scraping approach using Playwright in Python to collect the total transit time for each origin–destination pair under the wheelchair‑accessible constraint.
#
# ### 1. The scraping pipeline automatically performs the following steps for each route:
#
# ### 2. Navigate to Google Maps and select the “Directions” panel.
#
# ### 3. Input the origin and destination stations, which have been preprocessed to ensure that Google Maps can correctly identify the locations.
#
# ### 4. Switch to transit mode and open the route options to enable the “Wheelchair accessible” filter, as this is not supported by the public API.
#
# ### 5. Select the first suggested route card, expand its details, and extract the total commute time from the page (e.g. 1 hr 12 min convert to 72 minutes).
#
# ### 6. Record the result in a structured dataset for subsequent analysis, while logging any errors for retry or manual inspection.
#
# ### This approach leverages asynchronous Playwright for headless browser automation, combined with regular expressions to parse mixed “hours and minutes” text into numeric total minutes. The scraping script iterates over all routes in the dataset and outputs a final CSV file with the corresponding total commute times for wheelchair‑accessible travel.

# %%
# !pip install nest_asyncio
# !pip install -q playwright
# !playwright install --with-deps chromium
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 MB 22.9 MB/s eta 0:00:00
# Installing dependencies...
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,775 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,103 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,290 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,168 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,270 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,207 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,518 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,575 kB]
# Fetched 32.3 MB in 3s (11.3 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libasound2 set to manually installed.
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk-bridge2.0-0 set to manually installed.
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatk1.0-0 set to manually installed.
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libatspi2.0-0 set to manually installed.
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libcairo2 set to manually installed.
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcb1 set to manually installed.
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxcomposite1 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxdamage1 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxfixes3 set to manually installed.
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxkbcommon0 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.11).
# libcups2 set to manually installed.
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdbus-1-3 set to manually installed.
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libdrm2 set to manually installed.
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.3).
# libfreetype6 set to manually installed.
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgbm1 set to manually installed.
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.5).
# libnspr4 is already the newest version (2:4.35-0ubuntu0.22.04.1).
# libnspr4 set to manually installed.
# libnss3 is already the newest version (2:3.98-0ubuntu0.22.04.2).
# libnss3 set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-client0 set to manually installed.
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-6 set to manually installed.
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.15).
# The following additional packages will be installed:
#   xfonts-encodings xfonts-utils
# Recommended packages:
#   fonts-ipafont-mincho fonts-tlwg-loma
# The following NEW packages will be installed:
#   fonts-freefont-ttf fonts-ipafont-gothic fonts-noto-color-emoji
#   fonts-tlwg-loma-otf fonts-unifont fonts-wqy-zenhei xfonts-cyrillic
#   xfonts-encodings xfonts-scalable xfonts-utils
# 0 upgraded, 10 newly installed, 0 to remove and 35 not upgraded.
# Need to get 28.4 MB of archives.
# After this operation, 67.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipafont-gothic all 00303-21ubuntu1 [3,513 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2,388 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-noto-color-emoji all 2.047-0ubuntu0.22.04.1 [10.0 MB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-loma-otf all 1:0.7.3-1 [107 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unifont all 1:14.0.01-1 [3,551 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-wqy-zenhei all 0.9.45-8 [7,472 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xfonts-cyrillic all 1:1.0.5 [386 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-scalable all 1:1.0.3-1.2ubuntu1 [306 kB]
# Fetched 28.4 MB in 1s (20.0 MB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 126284 files and directories currently installed.)
# Preparing to unpack .../0-fonts-ipafont-gothic_00303-21ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-21ubuntu1) ...
# Selecting previously unselected package fonts-freefont-ttf.
# Preparing to unpack .../1-fonts-freefont-ttf_20120503-10build1_all.deb ...
# Unpacking fonts-freefont-ttf (20120503-10build1) ...
# Selecting previously unselected package fonts-noto-color-emoji.
# Preparing to unpack .../2-fonts-noto-color-emoji_2.047-0ubuntu0.22.04.1_all.deb ...
# Unpacking fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Selecting previously unselected package fonts-tlwg-loma-otf.
# Preparing to unpack .../3-fonts-tlwg-loma-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-unifont.
# Preparing to unpack .../4-fonts-unifont_1%3a14.0.01-1_all.deb ...
# Unpacking fonts-unifont (1:14.0.01-1) ...
# Selecting previously unselected package fonts-wqy-zenhei.
# Preparing to unpack .../5-fonts-wqy-zenhei_0.9.45-8_all.deb ...
# Unpacking fonts-wqy-zenhei (0.9.45-8) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../6-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../7-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-cyrillic.
# Preparing to unpack .../8-xfonts-cyrillic_1%3a1.0.5_all.deb ...
# Unpacking xfonts-cyrillic (1:1.0.5) ...
# Selecting previously unselected package xfonts-scalable.
# Preparing to unpack .../9-xfonts-scalable_1%3a1.0.3-1.2ubuntu1_all.deb ...
# Unpacking xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Setting up fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Setting up fonts-wqy-zenhei (0.9.45-8) ...
# Setting up fonts-freefont-ttf (20120503-10build1) ...
# Setting up fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up fonts-ipafont-gothic (00303-21ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-gothic/ipag.ttf to provide /usr/share/fonts/truetype/fonts-japanese-gothic.ttf (fonts-japanese-gothic.ttf) in auto mode
# Setting up fonts-unifont (1:14.0.01-1) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-cyrillic (1:1.0.5) ...
# Setting up xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Downloading Chromium 139.0.7258.5 (playwright build v1181) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1181/chromium-linux.zip
# 172.5 MiB [] 0% 131.3s172.5 MiB [] 0% 33.9s172.5 MiB [] 0% 11.4s172.5 MiB [] 1% 4.4s172.5 MiB [] 2% 3.0s172.5 MiB [] 3% 2.3s172.5 MiB [] 4% 2.3s172.5 MiB [] 5% 2.2s172.5 MiB [] 6% 2.1s172.5 MiB [] 7% 2.1s172.5 MiB [] 8% 1.9s172.5 MiB [] 9% 1.9s172.5 MiB [] 10% 1.8s172.5 MiB [] 12% 1.6s172.5 MiB [] 13% 1.5s172.5 MiB [] 14% 1.5s172.5 MiB [] 16% 1.4s172.5 MiB [] 18% 1.3s172.5 MiB [] 19% 1.3s172.5 MiB [] 21% 1.2s172.5 MiB [] 22% 1.1s172.5 MiB [] 24% 1.1s172.5 MiB [] 25% 1.1s172.5 MiB [] 26% 1.1s172.5 MiB [] 27% 1.1s172.5 MiB [] 29% 1.0s172.5 MiB [] 30% 1.0s172.5 MiB [] 32% 0.9s172.5 MiB [] 34% 0.9s172.5 MiB [] 36% 0.9s172.5 MiB [] 37% 0.9s172.5 MiB [] 39% 0.8s172.5 MiB [] 41% 0.8s172.5 MiB [] 43% 0.7s172.5 MiB [] 44% 0.7s172.5 MiB [] 47% 0.7s172.5 MiB [] 49% 0.6s172.5 MiB [] 51% 0.6s172.5 MiB [] 53% 0.6s172.5 MiB [] 55% 0.5s172.5 MiB [] 57% 0.5s172.5 MiB [] 59% 0.5s172.5 MiB [] 60% 0.5s172.5 MiB [] 63% 0.4s172.5 MiB [] 65% 0.4s172.5 MiB [] 68% 0.4s172.5 MiB [] 70% 0.3s172.5 MiB [] 72% 0.3s172.5 MiB [] 74% 0.3s172.5 MiB [] 75% 0.3s172.5 MiB [] 77% 0.2s172.5 MiB [] 79% 0.2s172.5 MiB [] 80% 0.2s172.5 MiB [] 81% 0.2s172.5 MiB [] 82% 0.2s172.5 MiB [] 83% 0.2s172.5 MiB [] 84% 0.2s172.5 MiB [] 86% 0.1s172.5 MiB [] 88% 0.1s172.5 MiB [] 90% 0.1s172.5 MiB [] 92% 0.1s172.5 MiB [] 94% 0.1s172.5 MiB [] 96% 0.0s172.5 MiB [] 97% 0.0s172.5 MiB [] 98% 0.0s172.5 MiB [] 100% 0.0s
# Chromium 139.0.7258.5 (playwright build v1181) downloaded to /root/.cache/ms-playwright/chromium-1181
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-linux.zip
# 2.3 MiB [] 0% 0.0s2.3 MiB [] 6% 0.3s2.3 MiB [] 39% 0.1s2.3 MiB [] 100% 0.0s
# FFMPEG playwright build v1011 downloaded to /root/.cache/ms-playwright/ffmpeg-1011
# Downloading Chromium Headless Shell 139.0.7258.5 (playwright build v1181) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1181/chromium-headless-shell-linux.zip
# 104.8 MiB [] 0% 0.0s104.8 MiB [] 0% 13.5s104.8 MiB [] 0% 4.2s104.8 MiB [] 2% 2.2s104.8 MiB [] 3% 1.6s104.8 MiB [] 5% 1.3s104.8 MiB [] 7% 1.2s104.8 MiB [] 8% 1.2s104.8 MiB [] 10% 1.2s104.8 MiB [] 11% 1.1s104.8 MiB [] 14% 1.0s104.8 MiB [] 15% 1.0s104.8 MiB [] 17% 0.9s104.8 MiB [] 19% 0.9s104.8 MiB [] 21% 0.9s104.8 MiB [] 23% 0.8s104.8 MiB [] 25% 0.8s104.8 MiB [] 27% 0.8s104.8 MiB [] 30% 0.7s104.8 MiB [] 33% 0.6s104.8 MiB [] 35% 0.6s104.8 MiB [] 38% 0.6s104.8 MiB [] 40% 0.5s104.8 MiB [] 41% 0.5s104.8 MiB [] 42% 0.5s104.8 MiB [] 43% 0.6s104.8 MiB [] 45% 0.5s104.8 MiB [] 47% 0.5s104.8 MiB [] 49% 0.5s104.8 MiB [] 52% 0.4s104.8 MiB [] 54% 0.4s104.8 MiB [] 57% 0.4s104.8 MiB [] 60% 0.4s104.8 MiB [] 63% 0.3s104.8 MiB [] 66% 0.3s104.8 MiB [] 68% 0.3s104.8 MiB [] 71% 0.2s104.8 MiB [] 73% 0.2s104.8 MiB [] 76% 0.2s104.8 MiB [] 79% 0.2s104.8 MiB [] 82% 0.1s104.8 MiB [] 85% 0.1s104.8 MiB [] 88% 0.1s104.8 MiB [] 91% 0.1s104.8 MiB [] 93% 0.0s104.8 MiB [] 94% 0.0s104.8 MiB [] 96% 0.0s104.8 MiB [] 98% 0.0s104.8 MiB [] 99% 0.0s104.8 MiB [] 100% 0.0s
# Chromium Headless Shell 139.0.7258.5 (playwright build v1181) downloaded to /root/.cache/ms-playwright/chromium_headless_shell-1181

# %%
import pandas as pd
import re, asyncio
from playwright.async_api import async_playwright

df = pd.read_csv("frequent_routes_final.csv")
df["commute_time"] = None

# commute time
async def get_commute_time_final(origin: str, destination: str):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context(locale="en-GB", timezone_id="Europe/London")
        page = await context.new_page()

        await page.goto("https://www.google.com/maps?hl=en", timeout=0)
        await page.click('button[aria-label="Directions"]')
        await page.fill('input[aria-label^="Choose starting"]', origin)
        await page.fill('input[aria-label^="Choose destination"]', destination)
        await page.keyboard.press("Enter")
        await asyncio.sleep(4)
        #await page.click('button[aria-label*="Transit"]')
        await page.locator('button[role="radio"] div[role="img"][aria-label="Transit"]').click(timeout=5000)
        await asyncio.sleep(1)

        try:
            await page.click('button[aria-label*="Options"]', timeout=5_000)
        except:
            await page.click('text=Options', timeout=5_000)
        await page.click('text=Wheelchair accessible')
        await asyncio.sleep(3)

        await page.wait_for_selector('div[role="listitem"]', timeout=30_000)
        first_card = page.locator('div[role="listitem"]').first
        try:
            await first_card.locator('text=Details').click(timeout=5_000)
        except:
            await first_card.click()

        await page.wait_for_selector("div.Fk3sm", timeout=10_000)
        time_text = await page.locator("div.Fk3sm").first.inner_text()
        print(f"-- Raw time text: {time_text}")

        match = re.search(r"(?:(\d+)\s*hr[s]?)?\s*(\d+)?\s*min", time_text.lower())
        if match:
            hours = int(match.group(1)) if match.group(1) else 0
            minutes = int(match.group(2)) if match.group(2) else 0
            total_minutes = hours * 60 + minutes
        else:
            total_minutes = None

        await browser.close()
        return total_minutes

N = len(df)

async def process_multiple_rows():
    for idx in range(N):
        row = df.loc[idx]
        origin = row["Start_Station"]
        dest = row["End_Station"]
        print(f"< Processing: {origin} → {dest} >")
        try:
            commute_time = await get_commute_time_final(origin, dest)
            df.at[idx, "commute_time"] = commute_time
            print(f"=>> {origin} → {dest}: {commute_time} min")
        except Exception as e:
            print(f"X Error for {origin} → {dest}: {e}")
            df.at[idx, "commute_time"] = "ERROR"

    df.to_csv("final_frequent_routes_with_commute.csv", index=False)
    print("Saved to 'final_frequent_routes_with_commute.csv'")

await process_multiple_rows()


from google.colab import files
files.download("final_frequent_routes_with_commute.csv")
# Out:
# < Processing: Wimbledon → Parsons Green >
# X Error for Wimbledon → Parsons Green: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Tooting Broadway → Clapham North >
# -- Raw time text: 31 min
# =>> Tooting Broadway → Clapham North: 31 min
# < Processing: Euston National Rail → Maida Vale >
# -- Raw time text: 39 min
# =>> Euston National Rail → Maida Vale: 39 min
# < Processing: Hammersmith Hammersmith & City → Ladbroke Grove >
# -- Raw time text: 34 min
# =>> Hammersmith Hammersmith & City → Ladbroke Grove: 34 min
# < Processing: Euston National Rail → Willesden Junction >
# -- Raw time text: 14 min
# =>> Euston National Rail → Willesden Junction: 14 min
# < Processing: Morden → Balham London Underground >
# -- Raw time text: 1 hr 5 min
# =>> Morden → Balham London Underground: 65 min
# < Processing: Romford → Manor Park >
# X Error for Romford → Manor Park: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Stratford → Seven Kings >
# -- Raw time text: 2 days 19 hr
# =>> Stratford → Seven Kings: None min
# < Processing: Barking → Elm Park >
# -- Raw time text: 1 day
# =>> Barking → Elm Park: None min
# < Processing: Uxbridge → Eastcote >
# -- Raw time text: 52 min
# =>> Uxbridge → Eastcote: 52 min
# < Processing: London Bridge London Underground → Canning Town >
# -- Raw time text: 33 min
# =>> London Bridge London Underground → Canning Town: 33 min
# < Processing: Ilford → Gidea Park >
# -- Raw time text: 4 hr 49 min
# =>> Ilford → Gidea Park: 289 min
# < Processing: Clapham Junction → Putney Bridge >
# -- Raw time text: 31 min
# =>> Clapham Junction → Putney Bridge: 31 min
# < Processing: Colindale → Belsize Park >
# -- Raw time text: 1 hr 6 min
# =>> Colindale → Belsize Park: 66 min
# < Processing: Paddington Transport for London → Southall >
# -- Raw time text: 30 min
# =>> Paddington Transport for London → Southall: 30 min
# < Processing: Brixton London Underground → Balham London Underground >
# -- Raw time text: 31 min
# =>> Brixton London Underground → Balham London Underground: 31 min
# < Processing: Stratford → Woodford >
# -- Raw time text: 3 days 5 hr
# =>> Stratford → Woodford: None min
# < Processing: Victoria London Underground → Clapham Common >
# -- Raw time text: 28 min
# =>> Victoria London Underground → Clapham Common: 28 min
# < Processing: Lewisham Docklands Light Railway → Island Gardens >
# X Error for Lewisham Docklands Light Railway → Island Gardens: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Shepherd's Bush London Underground → Perivale >
# -- Raw time text: 46 min
# =>> Shepherd's Bush London Underground → Perivale: 46 min
# < Processing: Clapham Common → Colliers Wood >
# -- Raw time text: 33 min
# =>> Clapham Common → Colliers Wood: 33 min
# < Processing: Tooting Broadway → Morden >
# -- Raw time text: 32 min
# =>> Tooting Broadway → Morden: 32 min
# < Processing: Clapham Junction → Queens Road Peckham >
# -- Raw time text: 17 min
# =>> Clapham Junction → Queens Road Peckham: 17 min
# < Processing: Wood Green → Cockfosters >
# -- Raw time text: 50 min
# =>> Wood Green → Cockfosters: 50 min
# < Processing: London Bridge London Underground → Stockwell >
# X Error for London Bridge London Underground → Stockwell: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Edgware → Golders Green >
# -- Raw time text: 45 min
# =>> Edgware → Golders Green: 45 min
# < Processing: Turnpike Lane → Oakwood >
# -- Raw time text: 2 hr 32 min
# =>> Turnpike Lane → Oakwood: 152 min
# < Processing: Balham London Underground → Morden >
# -- Raw time text: 53 min
# =>> Balham London Underground → Morden: 53 min
# < Processing: Woolwich Elizabeth Line → Abbey Wood >
# -- Raw time text: 25 min
# =>> Woolwich Elizabeth Line → Abbey Wood: 25 min
# < Processing: Canary Wharf Elizabeth Line → Abbey Wood >
# -- Raw time text: 1 hr
# =>> Canary Wharf Elizabeth Line → Abbey Wood: None min
# < Processing: Canary Wharf Docklands Light Railway → Island Gardens >
# X Error for Canary Wharf Docklands Light Railway → Island Gardens: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Brixton London Underground → Borough >
# X Error for Brixton London Underground → Borough: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Parsons Green → Wimbledon >
# X Error for Parsons Green → Wimbledon: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Woolwich Arsenal → Canning Town >
# -- Raw time text: 29 min
# =>> Woolwich Arsenal → Canning Town: 29 min
# < Processing: Heathrow Terminals 123 London Underground → Osterley >
# -- Raw time text: 30 min
# =>> Heathrow Terminals 123 London Underground → Osterley: 30 min
# < Processing: Hendon Central → Chalk Farm >
# -- Raw time text: 49 min
# =>> Hendon Central → Chalk Farm: 49 min
# < Processing: Cutty Sark → Heron Quays >
# -- Raw time text: 18 min
# =>> Cutty Sark → Heron Quays: 18 min
# < Processing: Walthamstow Central → Stoke Newington >
# -- Raw time text: 53 min
# =>> Walthamstow Central → Stoke Newington: 53 min
# < Processing: Heathrow Terminal 5 London Underground → Hounslow East >
# -- Raw time text: 14 min
# =>> Heathrow Terminal 5 London Underground → Hounslow East: 14 min
# < Processing: Manor House → Southgate >
# -- Raw time text: 1 day 7 hr
# =>> Manor House → Southgate: None min
# < Processing: Goodmayes → Maryland >
# X Error for Goodmayes → Maryland: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Colliers Wood → Clapham Common >
# -- Raw time text: 43 min
# =>> Colliers Wood → Clapham Common: 43 min
# < Processing: Tottenham Court Road → King's Cross St. Pancras >
# X Error for Tottenham Court Road → King's Cross St. Pancras: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: East Putney → Wimbledon >
# X Error for East Putney → Wimbledon: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Finchley Central → Kentish Town >
# -- Raw time text: 43 min
# =>> Finchley Central → Kentish Town: 43 min
# < Processing: Shenfield → Chadwell Heath >
# -- Raw time text: 45 min
# =>> Shenfield → Chadwell Heath: 45 min
# < Processing: Southfields → West Brompton >
# -- Raw time text: 52 min
# =>> Southfields → West Brompton: 52 min
# < Processing: Archway → Woodside Park >
# -- Raw time text: 12 hr 10 min
# =>> Archway → Woodside Park: 730 min
# < Processing: Paddington Transport for London → Wood Lane >
# X Error for Paddington Transport for London → Wood Lane: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: North Acton → South Ruislip >
# -- Raw time text: 1 hr 17 min
# =>> North Acton → South Ruislip: 77 min
# < Processing: Shepherd's Bush Market → Royal Oak >
# X Error for Shepherd's Bush Market → Royal Oak: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Tooting Bec → Morden >
# -- Raw time text: 49 min
# =>> Tooting Bec → Morden: 49 min
# < Processing: Paddington Transport for London → Baker Street >
# X Error for Paddington Transport for London → Baker Street: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Farringdon → King's Cross St. Pancras >
# -- Raw time text: 14 min
# =>> Farringdon → King's Cross St. Pancras: 14 min
# < Processing: Southgate → Manor House >
# -- Raw time text: 6 hr 59 min
# =>> Southgate → Manor House: 419 min
# < Processing: Archway → Euston London Underground >
# X Error for Archway → Euston London Underground: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Waterloo London Underground → Bank and Monument >
# -- Raw time text: 30 min
# =>> Waterloo London Underground → Bank and Monument: 30 min
# < Processing: Reading → Slough >
# X Error for Reading → Slough: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Ealing Broadway → Heathrow Terminals 2 & 3 Elizabeth Line >
# -- Raw time text: 24 min
# =>> Ealing Broadway → Heathrow Terminals 2 & 3 Elizabeth Line: 24 min
# < Processing: Ealing Broadway → West Ealing >
# -- Raw time text: 14 min
# =>> Ealing Broadway → West Ealing: 14 min
# < Processing: Golders Green → Edgware >
# -- Raw time text: 51 min
# =>> Golders Green → Edgware: 51 min
# < Processing: King's Cross St. Pancras → Farringdon >
# -- Raw time text: 19 min
# =>> King's Cross St. Pancras → Farringdon: 19 min
# < Processing: Leicester Square → Green Park >
# X Error for Leicester Square → Green Park: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Upminster → Dagenham Heathway >
# -- Raw time text: 19 min
# =>> Upminster → Dagenham Heathway: 19 min
# < Processing: Southfields → Wimbledon >
# -- Raw time text: 2 days 19 hr
# =>> Southfields → Wimbledon: None min
# < Processing: High Barnet → East Finchley >
# -- Raw time text: 49 min
# =>> High Barnet → East Finchley: 49 min
# < Processing: Notting Hill Gate → North Acton >
# -- Raw time text: 55 min
# =>> Notting Hill Gate → North Acton: 55 min
# < Processing: Tottenham Court Road → Green Park >
# -- Raw time text: 9 hr 40 min
# =>> Tottenham Court Road → Green Park: 580 min
# < Processing: Barking → Walthamstow Queen's Road >
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=TargetClosedError('Target page, context or browser has been closed')>
# playwright._impl._errors.TargetClosedError: Target page, context or browser has been closed
# X Error for Barking → Walthamstow Queen's Road: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Richmond → Willesden Junction >
# X Error for Richmond → Willesden Junction: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Colindale → Edgware >
# -- Raw time text: 38 min
# =>> Colindale → Edgware: 38 min
# < Processing: Maidenhead → Iver >
# X Error for Maidenhead → Iver: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("text=Options")
#     - locator resolved to <div class="BunUDe">…</div>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="fTryM">Did you mean:</div> from <div id="omnibox-container" class="JLm1tf-bEDTcc-GWbSKc id-omnibox-container">…</div> subtree intercepts pointer events
#     - retrying click action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="fTryM">Did you mean:</div> from <div id="omnibox-container" class="JLm1tf-bEDTcc-GWbSKc id-omnibox-container">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 100ms
#     9 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="fTryM">Did you mean:</div> from <div id="omnibox-container" class="JLm1tf-bEDTcc-GWbSKc id-omnibox-container">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 500ms
#     - waiting for element to be visible, enabled and stable
#
# < Processing: Waterloo London Underground → Battersea Power Station >
# -- Raw time text: 35 min
# =>> Waterloo London Underground → Battersea Power Station: 35 min
# < Processing: Highgate → Totteridge & Whetstone >
# X Error for Highgate → Totteridge & Whetstone: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Waterloo London Underground → Green Park >
# X Error for Waterloo London Underground → Green Park: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Tottenham Court Road → Bank and Monument >
# X Error for Tottenham Court Road → Bank and Monument: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: King's Cross St. Pancras → Oxford Circus >
# -- Raw time text: 5 min
# =>> King's Cross St. Pancras → Oxford Circus: 5 min
# < Processing: King's Cross St. Pancras → Bank and Monument >
# -- Raw time text: 12 min
# =>> King's Cross St. Pancras → Bank and Monument: 12 min
# < Processing: Ealing Broadway → West Drayton >
# -- Raw time text: 18 min
# =>> Ealing Broadway → West Drayton: 18 min
# < Processing: Shepherd's Bush London Underground → Marble Arch >
# -- Raw time text: 33 min
# =>> Shepherd's Bush London Underground → Marble Arch: 33 min
# < Processing: Paddington Transport for London → Oxford Circus >
# -- Raw time text: 27 min
# =>> Paddington Transport for London → Oxford Circus: 27 min
# < Processing: Chalk Farm → Hendon Central >
# -- Raw time text: 50 min
# =>> Chalk Farm → Hendon Central: 50 min
# < Processing: Victoria London Underground → Charing Cross London Underground >
# -- Raw time text: 20 min
# =>> Victoria London Underground → Charing Cross London Underground: 20 min
# < Processing: Canary Wharf London Underground → Waterloo London Underground >
# -- Raw time text: 10 min
# =>> Canary Wharf London Underground → Waterloo London Underground: 10 min
# < Processing: Clapham South → South Wimbledon >
# -- Raw time text: 46 min
# =>> Clapham South → South Wimbledon: 46 min
# < Processing: Hayes & Harlington → Acton Main Line >
# -- Raw time text: 12 min
# =>> Hayes & Harlington → Acton Main Line: 12 min
# < Processing: Cutty Sark → Lewisham Docklands Light Railway >
# -- Raw time text: 17 min
# =>> Cutty Sark → Lewisham Docklands Light Railway: 17 min
# < Processing: West Hampstead London Underground → Wembley Park >
# -- Raw time text: 38 min
# =>> West Hampstead London Underground → Wembley Park: 38 min
# < Processing: North Greenwich → Stratford >
# -- Raw time text: 16 min
# =>> North Greenwich → Stratford: 16 min
# < Processing: Stratford → Canada Water >
# -- Raw time text: 20 min
# =>> Stratford → Canada Water: 20 min
# < Processing: Woodford → Stratford >
# -- Raw time text: 2 days 13 hr
# =>> Woodford → Stratford: None min
# < Processing: Goodmayes → Brentwood >
# X Error for Goodmayes → Brentwood: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Victoria London Underground → Tottenham Court Road >
# X Error for Victoria London Underground → Tottenham Court Road: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Colliers Wood → Morden >
# -- Raw time text: 20 min
# =>> Colliers Wood → Morden: 20 min
# < Processing: Blackhorse Road → Rectory Road >
# X Error for Blackhorse Road → Rectory Road: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Clapham Common → Victoria London Underground >
# -- Raw time text: 33 min
# =>> Clapham Common → Victoria London Underground: 33 min
# < Processing: Custom House → Gallions Reach >
# X Error for Custom House → Gallions Reach: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Oxford Circus → Tottenham Court Road >
# -- Raw time text: 23 hr 50 min
# =>> Oxford Circus → Tottenham Court Road: 1430 min
# < Processing: Clapton → Seven Sisters >
# -- Raw time text: 3 hr 41 min
# =>> Clapton → Seven Sisters: 221 min
# < Processing: South Wimbledon → Clapham South >
# -- Raw time text: 40 min
# =>> South Wimbledon → Clapham South: 40 min
# < Processing: Canary Wharf London Underground → Honor Oak Park >
# -- Raw time text: 49 min
# =>> Canary Wharf London Underground → Honor Oak Park: 49 min
# < Processing: Fulham Broadway → Wimbledon Park >
# -- Raw time text: 37 min
# =>> Fulham Broadway → Wimbledon Park: 37 min
# < Processing: Slough → Reading >
# X Error for Slough → Reading: Page.wait_for_selector: Timeout 10000ms exceeded.
# Call log:
#   - waiting for locator("div.Fk3sm") to be visible
#
# < Processing: Victoria London Underground → Stockwell >
# X Error for Victoria London Underground → Stockwell: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Canary Wharf Elizabeth Line → Woolwich Elizabeth Line >
# -- Raw time text: 15 min
# =>> Canary Wharf Elizabeth Line → Woolwich Elizabeth Line: 15 min
# < Processing: Waterloo London Underground → Oxford Circus >
# -- Raw time text: 30 min
# =>> Waterloo London Underground → Oxford Circus: 30 min
# < Processing: East Ham → North Greenwich >
# -- Raw time text: 32 min
# =>> East Ham → North Greenwich: 32 min
# < Processing: Canary Wharf London Underground → London Bridge London Underground >
# -- Raw time text: 20 min
# =>> Canary Wharf London Underground → London Bridge London Underground: 20 min
# < Processing: Romford → Shenfield >
# -- Raw time text: 29 min
# =>> Romford → Shenfield: 29 min
# < Processing: Belsize Park → Colindale >
# -- Raw time text: 1 hr 6 min
# =>> Belsize Park → Colindale: 66 min
# < Processing: Piccadilly Circus → Tottenham Court Road >
# X Error for Piccadilly Circus → Tottenham Court Road: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Tottenham Court Road → Piccadilly Circus >
# X Error for Tottenham Court Road → Piccadilly Circus: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Epping → Woodford >
# X Error for Epping → Woodford: Page.wait_for_selector: Timeout 10000ms exceeded.
# Call log:
#   - waiting for locator("div.Fk3sm") to be visible
#
# < Processing: Custom House Elizabeth Line → Abbey Wood >
# -- Raw time text: 1 hr 1 min
# =>> Custom House Elizabeth Line → Abbey Wood: 61 min
# < Processing: Leicester Square → Bank and Monument >
# -- Raw time text: 31 min
# =>> Leicester Square → Bank and Monument: 31 min
# < Processing: Wood Lane → Paddington Transport for London >
# X Error for Wood Lane → Paddington Transport for London: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: King's Cross St. Pancras → Seven Sisters >
# X Error for King's Cross St. Pancras → Seven Sisters: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Putney Bridge → Wimbledon >
# X Error for Putney Bridge → Wimbledon: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Gants Hill → Stratford >
# X Error for Gants Hill → Stratford: Locator.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("button[role=\"radio\"] div[role=\"img\"][aria-label=\"Transit\"]")
#
# < Processing: Victoria London Underground → Oxford Circus >
# -- Raw time text: 43 min
# =>> Victoria London Underground → Oxford Circus: 43 min
# < Processing: Vauxhall London Underground → Balham London Underground >
# -- Raw time text: 44 min
# =>> Vauxhall London Underground → Balham London Underground: 44 min
# < Processing: Greenwich → South Quay >
# X Error for Greenwich → South Quay: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("text=Options")
#     - locator resolved to <div class="BunUDe">…</div>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div id="sbse11x0" class="f6FIGf" role="gridcell">…</div> from <div id="omnibox-container" class="JLm1tf-bEDTcc-GWbSKc id-omnibox-container">…</div> subtree intercepts pointer events
#     - retrying click action
#     - waiting 20ms
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - <div id="sbse11x0" class="f6FIGf" role="gridcell">…</div> from <div id="omnibox-container" class="JLm1tf-bEDTcc-GWbSKc id-omnibox-container">…</div> subtree intercepts pointer events
#   2 × retrying click action
#       - waiting 100ms
#       - waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <button vet="14442" class="YismEf" aria-label="Close directions" data-tooltip="Close directions" ved="1i:3,t:14442,e:2,p:FcKMaNCbLeTAkPIPycDBgAc:9" jsaction="directions.close; focus:pane.focusTooltip; blur:pane.blurTooltip; keydown:pane.escapeTooltip">…</button> from <div id="omnibox-container" class="JLm1tf-bEDTcc-GWbSKc id-omnibox-container">…</div> subtree intercepts pointer events
#   2 × retrying click action
#       - waiting 500ms
#       - waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div id="sbse11x0" class="f6FIGf" role="gridcell">…</div> from <div id="omnibox-container" class="JLm1tf-bEDTcc-GWbSKc id-omnibox-container">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 500ms
#       - waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div id="sbse11x0" class="f6FIGf" role="gridcell">…</div> from <div id="omnibox-container" class="JLm1tf-bEDTcc-GWbSKc id-omnibox-container">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 500ms
#       - waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <button vet="14442" class="YismEf" aria-label="Close directions" data-tooltip="Close directions" ved="1i:3,t:14442,e:2,p:FcKMaNCbLeTAkPIPycDBgAc:9" jsaction="directions.close; focus:pane.focusTooltip; blur:pane.blurTooltip; keydown:pane.escapeTooltip">…</button> from <div id="omnibox-container" class="JLm1tf-bEDTcc-GWbSKc id-omnibox-container">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 500ms
#       - waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <button vet="14442" class="YismEf" aria-label="Close directions" data-tooltip="Close directions" ved="1i:3,t:14442,e:2,p:FcKMaNCbLeTAkPIPycDBgAc:9" jsaction="directions.close; focus:pane.focusTooltip; blur:pane.blurTooltip; keydown:pane.escapeTooltip">…</button> from <div id="omnibox-container" class="JLm1tf-bEDTcc-GWbSKc id-omnibox-container">…</div> subtree intercepts pointer events
#   - retrying click action
#     - waiting 500ms
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - <div id="sbse11x0" class="f6FIGf" role="gridcell">…</div> from <div id="omnibox-container" class="JLm1tf-bEDTcc-GWbSKc id-omnibox-container">…</div> subtree intercepts pointer events
#   - retrying click action
#     - waiting 500ms
#
# Saved to 'final_frequent_routes_with_commute.csv'
